# %% [markdown]
# # Siamese Recurrent Architectures - MAGRU-ATTENTION
#
# In this notebook we evaluate a novel siamese architecture for sentence similarity task - MAGRU. It is an improvement to the architecture proposed in [this paper](https://www.aaai.org/ocs/index.php/AAAI/AAAI16/paper/download/12195/12023). We evaluate how the performance varies with different optimizers and different word vectors for this architecture using attention and compare it with MALSTM.

# %% [markdown]
# ### Loading Data
#
# #### STS Benchmark
# The STS Benchmark brings together the English data from the SemEval sentence similarity tasks between 2012 and 2017. The data is split in training, development and test data: http://ixa2.si.ehu.es/stswiki/index.php/STSbenchmark

# %%
from preprocessing.load_data import download_and_load_sts_data, download_and_load_sick_dataset

sts_dev, sts_test = download_and_load_sts_data()
sts_test[:10]
# Out:
#                                           sent_1  \
# 0                    A girl is styling her hair.
# 1       A group of men play soccer on the beach.
# 2  One woman is measuring another woman's ankle.
# 3                A man is cutting up a cucumber.
# 4                       A man is playing a harp.
# 5                     A woman is cutting onions.
# 6           A man is riding an electric bicycle.
# 7                    A man is playing the drums.
# 8                       A man is playing guitar.
# 9                     A man is playing a guitar.
#
#                                              sent_2    sim
# 0                      A girl is brushing her hair.  2.500
# 1  A group of boys are playing soccer on the beach.  3.600
# 2           A woman measures another woman's ankle.  5.000
# 3                      A man is slicing a cucumber.  4.200
# 4                      A man is playing a keyboard.  1.500
# 5                          A woman is cutting tofu.  1.800
# 6                        A man is riding a bicycle.  3.500
# 7                      A man is playing the guitar.  2.200
# 8                     A lady is playing the guitar.  2.200
# 9                       A man is playing a trumpet.  1.714

# %% [markdown]
# #### SICK data
# The SICK dataset contains 10,000 English sentence pairs labelled with their semantic relatedness and entailment relation.

# %%
sick_all, sick_train, sick_test, sick_dev = download_and_load_sick_dataset()
sick_all[:10]
# Out:
#   idx                                             sent_1  \
# 0   1  A group of kids is playing in a yard and an ol...
# 1   2  A group of children is playing in the house an...
# 2   3  The young boys are playing outdoors and the ma...
# 3   5  The kids are playing outdoors near a man with ...
# 4   9  The young boys are playing outdoors and the ma...
# 5  12                              Two dogs are fighting
# 6  14  A brown dog is attacking another animal in fro...
# 7  18  A brown dog is attacking another animal in fro...
# 8  25          Nobody is riding the bicycle on one wheel
# 9  26        A person is riding the bicycle on one wheel
#
#                                               sent_2  sim       label
# 0  A group of boys in a yard is playing and a man...  4.5     NEUTRAL
# 1  A group of kids is playing in a yard and an ol...  3.2     NEUTRAL
# 2  The kids are playing outdoors near a man with ...  4.7  ENTAILMENT
# 3  A group of kids is playing in a yard and an ol...  3.4     NEUTRAL
# 4  A group of kids is playing in a yard and an ol...  3.7     NEUTRAL
# 5                 Two dogs are wrestling and hugging  4.0     NEUTRAL
# 6                              Two dogs are fighting  3.5     NEUTRAL
# 7                 Two dogs are wrestling and hugging  3.2     NEUTRAL
# 8  A person in a black jacket is doing tricks on ...  2.8     NEUTRAL
# 9  A man in a black jacket is doing tricks on a m...  3.7     NEUTRAL

# %% [markdown]
# ### Loading Embeddings
# 3 word embeddings were used for this experiment. Word2vec, Glove and fasttext.
#
# #### Loading word2vec

# %%
from embeddings.load_embeddings import load_word2vec

word2vec = load_word2vec("/data/word2vec/GoogleNews-vectors-negative300.bin.gz")

# %% [markdown]
# #### Loading Glove
# To load Glove, we have to convert the downloaded GloVe file to word2vec format and then load the embeddings into a Gensim model.

# %%
from embeddings.load_embeddings import load_glove

glove = load_glove("/data/glove/glove.840B.300d.txt")

# %% [markdown]
# #### Loading Fasttext
# To load Fasttext, we used genism library

# %%
from embeddings.load_embeddings import load_fasttext

fasttext = load_fasttext("/data/fasttext/crawl-300d-2M-subword.vec")

# %% [markdown]
# #### Preparing Optimizers
# Following optimizers were used to the neural network architecture.

# %%
from keras.optimizers import Adadelta, SGD, RMSprop, Adagrad, Adam, Adamax, Nadam

gradient_clipping_norm = 1.25

adadelta = Adadelta(clipnorm=gradient_clipping_norm)
sgd = SGD(clipnorm=gradient_clipping_norm)
rmsprop = RMSprop(clipnorm=gradient_clipping_norm)
adagrad = Adagrad(clipnorm=gradient_clipping_norm)
adam = Adam(clipnorm=gradient_clipping_norm)
adamax = Adamax(clipnorm=gradient_clipping_norm)
nadam = Nadam(clipnorm=gradient_clipping_norm)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## MAGRU-ATTENTION with Adadelta
# In MAGRU the identical sub-network is all the way from the embedding up to the last GRU hidden state. We check the network with three word embeddings using adadelta optimizer.
#
# 1. MAGRU-ATTENTION with Word2vec
# 2. MAGRU-ATTENTION with Glove
# 3. MAGRU-ATTENTION with Fasttext

# %%
import functools as ft

from nn.gru_attention_manhattan import run_gru_attention_benchmark

validation_portion = 0.1
n_hidden = 100
embedding_dim = 300
batch_size = 64
n_epoch = 100

benchmarks = [("GRU-ATTENTION-W2V-ADADELTA",
               ft.partial(run_gru_attention_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=adadelta,
                          model=word2vec)),
              ("GRU-ATTENTION-GLOVE-ADADELTA",
               ft.partial(run_gru_attention_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=adadelta,
                          model=glove)),
              ("GRU-ATTENTION-FASTTEXT-ADADELTA",
               ft.partial(run_gru_attention_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=adadelta,
                          model=fasttext))]

# %%
from math import sqrt

import matplotlib.pyplot as plt
import pandas as pd
import scipy
from sklearn.metrics import mean_squared_error

from preprocessing.normalize import normalize
from utility.run_experiment import run_experiment

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(25, 10))
row = 0
column = 0
sick_train_normlized = normalize(sick_train, ["sim"])
sick_test_normalized = normalize(sick_test, ["sim"])
for i in range(0, 3):
    sims, trained_model, topic = run_experiment(sick_train_normlized, sick_test_normalized, ['sent_1', 'sent_2'], "sim",
                                                benchmarks[i])
    sick_test_normalized['predicted_sim'] = pd.Series(sims).values
    pearson_correlation = scipy.stats.pearsonr(sims, sick_test_normalized['sim'])[0]
    spearman_correlation = scipy.stats.spearmanr(sims, sick_test_normalized['sim'])[0]
    rmse = sqrt(mean_squared_error(sick_test_normalized['predicted_sim'], sick_test_normalized['sim']))
    textstr = 'RMSE=%.3f\n$Pearson Correlation=%.3f$\n$Spearman Correlation=%.3f$' % (
        rmse, pearson_correlation, spearman_correlation)
    sick_test_sorted = sick_test_normalized.sort_values('sim')
    id = list(range(0, len(sick_test_normalized.index)))
    sick_test_sorted['id'] = pd.Series(id).values

    if (i < 3):
        row = 0
        column = i

    sick_test_sorted.plot(kind='scatter', x='id', y='sim', color='DarkBlue', label='Similarity', title=topic,
                          ax=axes[column]);
    sick_test_sorted.plot(kind='scatter', x='id', y='predicted_sim', color='DarkGreen', label='Predicted Similarity',
                          ax=axes[column]);
    axes[column].text(1500, 0.05, textstr, fontsize=12)
# Out:
# /home/tharindu/Projects/Siamese-Recurrent-Architectures/preprocessing/embeddings.py:33: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   dataset.set_value(index, question, q2n)
# /home/tharindu/Projects/Siamese-Recurrent-Architectures/nn/gru_attention_manhattan.py:89: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   validation_data=([X_validation['left'], X_validation['right']], Y_validation))

# %% [markdown]
# ## MAGRU with SGD
# We check the network with three word embeddings using sgd optimizer.
#
# 1. MAGRU with Word2vec
# 2. MAGRU with Glove
# 3. MAGRU with Fasttext

# %%
import functools as ft

from nn.gru_manhattan import run_gru_benchmark

validation_portion = 0.1
n_hidden = 100
embedding_dim = 300
batch_size = 64
n_epoch = 100

benchmarks = [("GRU-W2V-SGD", ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                                         embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch,
                                         optimizer=sgd, model=word2vec)),
              ("GRU-GLOVE-SGD", ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                                           embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch,
                                           optimizer=sgd, model=glove)),
              ("GRU-FASTTEXT-SGD",
               ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=sgd,
                          model=fasttext))]

# %%
from math import sqrt

import matplotlib.pyplot as plt
import pandas as pd
import scipy
from sklearn.metrics import mean_squared_error

from preprocessing.normalize import normalize
from utility.run_experiment import run_experiment

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(25, 10))
row = 0
column = 0
sick_train_normlized = normalize(sick_train, ["sim"])
sick_test_normalized = normalize(sick_test, ["sim"])
for i in range(0, 3):
    sims, trained_model, topic = run_experiment(sick_train_normlized, sick_test_normalized, ['sent_1', 'sent_2'], "sim",
                                                benchmarks[i])
    sick_test_normalized['predicted_sim'] = pd.Series(sims).values
    pearson_correlation = scipy.stats.pearsonr(sims, sick_test_normalized['sim'])[0]
    spearman_correlation = scipy.stats.spearmanr(sims, sick_test_normalized['sim'])[0]
    rmse = sqrt(mean_squared_error(sick_test_normalized['predicted_sim'], sick_test_normalized['sim']))
    textstr = 'RMSE=%.3f\n$Pearson Correlation=%.3f$\n$Spearman Correlation=%.3f$' % (
        rmse, pearson_correlation, spearman_correlation)
    sick_test_sorted = sick_test_normalized.sort_values('sim')
    id = list(range(0, len(sick_test_normalized.index)))
    sick_test_sorted['id'] = pd.Series(id).values

    if (i < 3):
        row = 0
        column = i

    sick_test_sorted.plot(kind='scatter', x='id', y='sim', color='DarkBlue', label='Similarity', title=topic,
                          ax=axes[column]);
    sick_test_sorted.plot(kind='scatter', x='id', y='predicted_sim', color='DarkGreen', label='Predicted Similarity',
                          ax=axes[column]);
    axes[column].text(1500, 0.05, textstr, fontsize=12)
# Out:
# /home/tharindu/Projects/Siamese-Recurrent-Architectures/preprocessing/embeddings.py:33: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   dataset.set_value(index, question, q2n)
# /home/tharindu/Projects/Siamese-Recurrent-Architectures/nn/gru_manhattan.py:95: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   callbacks=callbacks)

# %% [markdown]
# ## MAGRU with RMSPROP
# We check the network with three word embeddings using rmsprop optimizer.
#
# 1. MAGRU with Word2vec
# 2. MAGRU with Glove
# 3. MAGRU with Fasttext

# %%
import functools as ft

from nn.gru_manhattan import run_gru_benchmark

validation_portion = 0.1
n_hidden = 100
embedding_dim = 300
batch_size = 64
n_epoch = 100

benchmarks = [("GRU-W2V-RMSPROP",
               ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=rmsprop,
                          model=word2vec)),
              ("GRU-GLOVE-RMSPROP",
               ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=rmsprop,
                          model=glove)),
              ("GRU-FASTTEXT-RMSPROP",
               ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=rmsprop,
                          model=fasttext))]

# %%
from math import sqrt

import matplotlib.pyplot as plt
import pandas as pd
import scipy
from sklearn.metrics import mean_squared_error

from preprocessing.normalize import normalize
from utility.run_experiment import run_experiment

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(25, 10))
row = 0
column = 0
sick_train_normlized = normalize(sick_train, ["sim"])
sick_test_normalized = normalize(sick_test, ["sim"])
for i in range(0, 3):
    sims, trained_model, topic = run_experiment(sick_train_normlized, sick_test_normalized, ['sent_1', 'sent_2'], "sim",
                                                benchmarks[i])
    sick_test_normalized['predicted_sim'] = pd.Series(sims).values
    pearson_correlation = scipy.stats.pearsonr(sims, sick_test_normalized['sim'])[0]
    spearman_correlation = scipy.stats.spearmanr(sims, sick_test_normalized['sim'])[0]
    rmse = sqrt(mean_squared_error(sick_test_normalized['predicted_sim'], sick_test_normalized['sim']))
    textstr = 'RMSE=%.3f\n$Pearson Correlation=%.3f$\n$Spearman Correlation=%.3f$' % (
        rmse, pearson_correlation, spearman_correlation)
    sick_test_sorted = sick_test_normalized.sort_values('sim')
    id = list(range(0, len(sick_test_normalized.index)))
    sick_test_sorted['id'] = pd.Series(id).values

    if (i < 3):
        row = 0
        column = i

    sick_test_sorted.plot(kind='scatter', x='id', y='sim', color='DarkBlue', label='Similarity', title=topic,
                          ax=axes[column]);
    sick_test_sorted.plot(kind='scatter', x='id', y='predicted_sim', color='DarkGreen', label='Predicted Similarity',
                          ax=axes[column]);
    axes[column].text(1500, 0.05, textstr, fontsize=12)
# Out:
# /home/tharindu/Projects/Siamese-Recurrent-Architectures/preprocessing/embeddings.py:33: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   dataset.set_value(index, question, q2n)
# /home/tharindu/Projects/Siamese-Recurrent-Architectures/nn/gru_manhattan.py:95: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   callbacks=callbacks)
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0001.

# %% [markdown]
# ## MAGRU with ADAGRAD
# We check the network with three word embeddings using adagrad optimizer.
#
# 1. MAGRU with Word2vec
# 2. MAGRU with Glove
# 3. MAGRU with Fasttext

# %%
import functools as ft

from nn.gru_manhattan import run_gru_benchmark

validation_portion = 0.1
n_hidden = 100
embedding_dim = 300
batch_size = 64
n_epoch = 100

benchmarks = [("GRU-W2V-ADAGRAD",
               ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=adagrad,
                          model=word2vec)),
              ("GRU-GLOVE-ADAGRAD",
               ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=adagrad,
                          model=glove)),
              ("GRU-FASTTEXT-ADAGRAD",
               ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=adagrad,
                          model=fasttext))]

# %%
from math import sqrt

import matplotlib.pyplot as plt
import pandas as pd
import scipy
from sklearn.metrics import mean_squared_error

from preprocessing.normalize import normalize
from utility.run_experiment import run_experiment

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(25, 10))
row = 0
column = 0
sick_train_normlized = normalize(sick_train, ["sim"])
sick_test_normalized = normalize(sick_test, ["sim"])
for i in range(0, 3):
    sims, trained_model, topic = run_experiment(sick_train_normlized, sick_test_normalized, ['sent_1', 'sent_2'], "sim",
                                                benchmarks[i])
    sick_test_normalized['predicted_sim'] = pd.Series(sims).values
    pearson_correlation = scipy.stats.pearsonr(sims, sick_test_normalized['sim'])[0]
    spearman_correlation = scipy.stats.spearmanr(sims, sick_test_normalized['sim'])[0]
    rmse = sqrt(mean_squared_error(sick_test_normalized['predicted_sim'], sick_test_normalized['sim']))
    textstr = 'RMSE=%.3f\n$Pearson Correlation=%.3f$\n$Spearman Correlation=%.3f$' % (
        rmse, pearson_correlation, spearman_correlation)
    sick_test_sorted = sick_test_normalized.sort_values('sim')
    id = list(range(0, len(sick_test_normalized.index)))
    sick_test_sorted['id'] = pd.Series(id).values

    if (i < 3):
        row = 0
        column = i

    sick_test_sorted.plot(kind='scatter', x='id', y='sim', color='DarkBlue', label='Similarity', title=topic,
                          ax=axes[column]);
    sick_test_sorted.plot(kind='scatter', x='id', y='predicted_sim', color='DarkGreen', label='Predicted Similarity',
                          ax=axes[column]);
    axes[column].text(1500, 0.05, textstr, fontsize=12)
# Out:
# /home/tharindu/Projects/Siamese-Recurrent-Architectures/preprocessing/embeddings.py:33: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   dataset.set_value(index, question, q2n)
# /home/tharindu/Projects/Siamese-Recurrent-Architectures/nn/gru_manhattan.py:95: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   callbacks=callbacks)

# %% [markdown]
# ## MAGRU with ADAM
# We check the network with three word embeddings using adam optimizer.
#
# 1. MAGRU with Word2vec
# 2. MAGRU with Glove
# 3. MAGRU with Fasttext

# %%
import functools as ft

from nn.gru_manhattan import run_gru_benchmark

validation_portion = 0.1
n_hidden = 100
embedding_dim = 300
batch_size = 64
n_epoch = 100

benchmarks = [("GRU-W2V-ADAM", ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch,
                                          optimizer=adam, model=word2vec)),
              ("GRU-GLOVE-ADAM", ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                                            embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch,
                                            optimizer=adam, model=glove)),
              ("GRU-FASTTEXT-ADAM",
               ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=adam,
                          model=fasttext))]

# %%
from math import sqrt

import matplotlib.pyplot as plt
import pandas as pd
import scipy
from sklearn.metrics import mean_squared_error

from preprocessing.normalize import normalize
from utility.run_experiment import run_experiment

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(25, 10))
row = 0
column = 0
sick_train_normlized = normalize(sick_train, ["sim"])
sick_test_normalized = normalize(sick_test, ["sim"])
for i in range(0, 3):
    sims, trained_model, topic = run_experiment(sick_train_normlized, sick_test_normalized, ['sent_1', 'sent_2'], "sim",
                                                benchmarks[i])
    sick_test_normalized['predicted_sim'] = pd.Series(sims).values
    pearson_correlation = scipy.stats.pearsonr(sims, sick_test_normalized['sim'])[0]
    spearman_correlation = scipy.stats.spearmanr(sims, sick_test_normalized['sim'])[0]
    rmse = sqrt(mean_squared_error(sick_test_normalized['predicted_sim'], sick_test_normalized['sim']))
    textstr = 'RMSE=%.3f\n$Pearson Correlation=%.3f$\n$Spearman Correlation=%.3f$' % (
        rmse, pearson_correlation, spearman_correlation)
    sick_test_sorted = sick_test_normalized.sort_values('sim')
    id = list(range(0, len(sick_test_normalized.index)))
    sick_test_sorted['id'] = pd.Series(id).values

    if (i < 3):
        row = 0
        column = i

    sick_test_sorted.plot(kind='scatter', x='id', y='sim', color='DarkBlue', label='Similarity', title=topic,
                          ax=axes[column]);
    sick_test_sorted.plot(kind='scatter', x='id', y='predicted_sim', color='DarkGreen', label='Predicted Similarity',
                          ax=axes[column]);
    axes[column].text(1500, 0.05, textstr, fontsize=12)
# Out:
# /home/tharindu/Projects/Siamese-Recurrent-Architectures/preprocessing/embeddings.py:33: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   dataset.set_value(index, question, q2n)
# /home/tharindu/Projects/Siamese-Recurrent-Architectures/nn/gru_manhattan.py:95: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   callbacks=callbacks)
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0001.

# %% [markdown]
# ## MAGRU with ADAMAX
#  We check the network with three word embeddings using adamax optimizer.
#
# 1. MAGRU with Word2vec
# 2. MAGRU with Glove
# 3. MAGRU with Fasttext

# %%
import functools as ft

from nn.gru_manhattan import run_gru_benchmark

validation_portion = 0.1
n_hidden = 100
embedding_dim = 300
batch_size = 64
n_epoch = 100

benchmarks = [("GRU-W2V-ADAMAX", ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                                            embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch,
                                            optimizer=adamax, model=word2vec)),
              ("GRU-GLOVE-ADAMAX",
               ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=adamax,
                          model=glove)),
              ("GRU-FASTTEXT-ADAMAX",
               ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=adamax,
                          model=fasttext))]

# %%
from math import sqrt

import matplotlib.pyplot as plt
import pandas as pd
import scipy
from sklearn.metrics import mean_squared_error

from preprocessing.normalize import normalize
from utility.run_experiment import run_experiment

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(25, 10))
row = 0
column = 0
sick_train_normlized = normalize(sick_train, ["sim"])
sick_test_normalized = normalize(sick_test, ["sim"])
for i in range(0, 3):
    sims, trained_model, topic = run_experiment(sick_train_normlized, sick_test_normalized, ['sent_1', 'sent_2'], "sim",
                                                benchmarks[i])
    sick_test_normalized['predicted_sim'] = pd.Series(sims).values
    pearson_correlation = scipy.stats.pearsonr(sims, sick_test_normalized['sim'])[0]
    spearman_correlation = scipy.stats.spearmanr(sims, sick_test_normalized['sim'])[0]
    rmse = sqrt(mean_squared_error(sick_test_normalized['predicted_sim'], sick_test_normalized['sim']))
    textstr = 'RMSE=%.3f\n$Pearson Correlation=%.3f$\n$Spearman Correlation=%.3f$' % (
        rmse, pearson_correlation, spearman_correlation)
    sick_test_sorted = sick_test_normalized.sort_values('sim')
    id = list(range(0, len(sick_test_normalized.index)))
    sick_test_sorted['id'] = pd.Series(id).values

    if (i < 3):
        row = 0
        column = i

    sick_test_sorted.plot(kind='scatter', x='id', y='sim', color='DarkBlue', label='Similarity', title=topic,
                          ax=axes[column]);
    sick_test_sorted.plot(kind='scatter', x='id', y='predicted_sim', color='DarkGreen', label='Predicted Similarity',
                          ax=axes[column]);
    axes[column].text(1500, 0.05, textstr, fontsize=12)
# Out:
# /home/tharindu/Projects/Siamese-Recurrent-Architectures/preprocessing/embeddings.py:33: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   dataset.set_value(index, question, q2n)
# /home/tharindu/Projects/Siamese-Recurrent-Architectures/nn/gru_manhattan.py:95: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   callbacks=callbacks)
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0012000000569969416.
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.000720000034198165.
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0004320000065490603.
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.00025920000043697653.
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.00015551999676972626.
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001.

# %% [markdown]
# ## MAGRU with NADAM
# We check the network with three word embeddings using nadam optimizer.
#
# 1. MAGRU with Word2vec
# 2. MAGRU with Glove
# 3. MAGRU with Fasttext

# %%
import functools as ft

from nn.gru_manhattan import run_gru_benchmark

validation_portion = 0.1
n_hidden = 100
embedding_dim = 300
batch_size = 64
n_epoch = 100

benchmarks = [("GRU-W2V-NADAM", ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                                           embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch,
                                           optimizer=nadam, model=word2vec)),
              ("GRU-GLOVE-NADAM",
               ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=nadam,
                          model=glove)),
              ("GRU-FASTTEXT-NADAM",
               ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=nadam,
                          model=fasttext))]

# %%
from math import sqrt

import matplotlib.pyplot as plt
import pandas as pd
import scipy
from sklearn.metrics import mean_squared_error

from preprocessing.normalize import normalize
from utility.run_experiment import run_experiment

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(25, 10))
row = 0
column = 0
sick_train_normlized = normalize(sick_train, ["sim"])
sick_test_normalized = normalize(sick_test, ["sim"])
for i in range(0, 3):
    sims, trained_model, topic = run_experiment(sick_train_normlized, sick_test_normalized, ['sent_1', 'sent_2'], "sim",
                                                benchmarks[i])
    sick_test_normalized['predicted_sim'] = pd.Series(sims).values
    pearson_correlation = scipy.stats.pearsonr(sims, sick_test_normalized['sim'])[0]
    spearman_correlation = scipy.stats.spearmanr(sims, sick_test_normalized['sim'])[0]
    rmse = sqrt(mean_squared_error(sick_test_normalized['predicted_sim'], sick_test_normalized['sim']))
    textstr = 'RMSE=%.3f\n$Pearson Correlation=%.3f$\n$Spearman Correlation=%.3f$' % (
        rmse, pearson_correlation, spearman_correlation)
    sick_test_sorted = sick_test_normalized.sort_values('sim')
    id = list(range(0, len(sick_test_normalized.index)))
    sick_test_sorted['id'] = pd.Series(id).values

    if (i < 3):
        row = 0
        column = i

    sick_test_sorted.plot(kind='scatter', x='id', y='sim', color='DarkBlue', label='Similarity', title=topic,
                          ax=axes[column]);
    sick_test_sorted.plot(kind='scatter', x='id', y='predicted_sim', color='DarkGreen', label='Predicted Similarity',
                          ax=axes[column]);
    axes[column].text(1500, 0.05, textstr, fontsize=12)
# Out:
# /home/tharindu/Projects/Siamese-Recurrent-Architectures/preprocessing/embeddings.py:33: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   dataset.set_value(index, question, q2n)
# /home/tharindu/Projects/Siamese-Recurrent-Architectures/nn/gru_manhattan.py:95: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   callbacks=callbacks)
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0012000000569969416.
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.000720000034198165.
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0004320000065490603.
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00025920000043697653.
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.00015551999676972626.
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0001.

# %% [markdown]
# ## Conclusions
# MAGRU model outperformed MALSTM model by a good margin. When used the same optimizer as with the MALSTM's original paper-adadelta, MAGRU improved the RMSE by 0.015. Best performance of MAGRU was given when Adam optimizer was used and it gave 0.021 improvement to the LSTM value.

# %% [markdown]
# ## MAGRU - Transfer Learning

# %% [markdown]
# Original paper of MALSTM uses transfer learning. We evaluated MAGRU performance with transfer learning. We first trained the MAGRU with STS data and then saved it. When we are training for the sick dataset we loaded those saved weights.

# %%
import functools as ft

from nn.gru_manhattan import run_gru_benchmark

validation_portion = 0.1
n_hidden = 100
embedding_dim = 300
batch_size = 64
n_epoch = 500

pre_benchmarks = [("GRU-W2V-ADADELTA",
                   ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                              embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=adadelta,
                              save_weights="models/gru_w2v_adadelta_weights.h5", load_weights=None, model=word2vec)),
                  ("GRU-GLOVE-ADADELTA",
                   ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                              embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=adadelta,
                              save_weights="models/gru_glove_adadelta_weights.h5", load_weights=None, model=glove)),
                  ("GRU-FASTTEXT-ADADELTA",
                   ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                              embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=adadelta,
                              save_weights="models/gru_fasttext_adadelta_weights.h5", load_weights=None,
                              model=fasttext))]

benchmarks = [("GRU-W2V-ADADELTA",
               ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=adadelta,
                          save_weights=None, load_weights="models/gru_w2v_adadelta_weights.h5", model=word2vec)),
              ("GRU-GLOVE-ADADELTA",
               ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=adadelta,
                          save_weights=None, load_weights="models/gru_glove_adadelta_weights.h5", model=glove)),
              ("GRU-FASTTEXT-ADADELTA",
               ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=adadelta,
                          save_weights=None, load_weights="models/gru_fasttext_adadelta_weights.h5", model=fasttext))]

# %%
from math import sqrt

import matplotlib.pyplot as plt
import pandas as pd
import scipy
from sklearn.metrics import mean_squared_error

from preprocessing.normalize import normalize
from utility.run_experiment import run_experiment

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(25, 10))
row = 0
column = 0
sts_all = sts_dev.append(sts_test, ignore_index=True)
sts_all_normalized = normalize(sts_all, ["sim"])
sick_train_normlized = normalize(sick_train, ["sim"])
sick_test_normalized = normalize(sick_test, ["sim"])
for i in range(0, 3):
    sts_sims, sts_trained_model, topic = run_experiment(sts_all_normalized, sts_all_normalized, ['sent_1', 'sent_2'],
                                                        "sim", pre_benchmarks[i])
    sims, trained_model, topic = run_experiment(sick_train_normlized, sick_test_normalized, ['sent_1', 'sent_2'], "sim",
                                                benchmarks[i])
    sick_test_normalized['predicted_sim'] = pd.Series(sims).values
    pearson_correlation = scipy.stats.pearsonr(sims, sick_test_normalized['sim'])[0]
    spearman_correlation = scipy.stats.spearmanr(sims, sick_test_normalized['sim'])[0]
    rmse = sqrt(mean_squared_error(sick_test_normalized['predicted_sim'], sick_test_normalized['sim']))
    textstr = 'RMSE=%.3f\n$Pearson Correlation=%.3f$\n$Spearman Correlation=%.3f$' % (
        rmse, pearson_correlation, spearman_correlation)
    sick_test_sorted = sick_test_normalized.sort_values('sim')
    id = list(range(0, len(sick_test_normalized.index)))
    sick_test_sorted['id'] = pd.Series(id).values

    if i < 3:
        row = 0
        column = i

    sick_test_sorted.plot(kind='scatter', x='id', y='sim', color='DarkBlue', label='Similarity', title=topic,
                          ax=axes[column]);
    sick_test_sorted.plot(kind='scatter', x='id', y='predicted_sim', color='DarkGreen', label='Predicted Similarity',
                          ax=axes[column]);
    axes[column].text(1500, 0.05, textstr, fontsize=12)
# Out:
# /home/tharindu/Projects/Siamese-Recurrent-Architectures/preprocessing/embeddings.py:33: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   dataset.set_value(index, question, q2n)
# /home/tharindu/Projects/Siamese-Recurrent-Architectures/nn/gru_manhattan.py:89: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   callbacks=callbacks)
# Epoch 00001: val_loss improved from inf to 0.25521, saving model to models/gru_w2v_adadelta_weights.h5
#
# Epoch 00002: val_loss did not improve from 0.25521
#
# Epoch 00002: ReduceLROnPlateau reducing learning rate to 0.6.
#
# Epoch 00003: val_loss improved from 0.25521 to 0.23453, saving model to models/gru_w2v_adadelta_weights.h5
#
# Epoch 00004: val_loss did not improve from 0.23453
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.36000001430511475.
#
# Epoch 00005: val_loss did not improve from 0.23453
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.21600000858306884.
#
# Epoch 00006: val_loss did not improve from 0.23453
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.12960000336170197.
#
# Epoch 00007: val_loss improved from 0.23453 to 0.23355, saving model to models/gru_w2v_adadelta_weights.h5
#
# Epoch 00008: val_loss did not improve from 0.23355
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.07776000201702117.
#
# Epoch 00009: val_loss improved from 0.23355 to 0.23261, saving model to models/gru_w2v_adadelta_weights.h5
#
# Epoch 00010: val_loss did not improve from 0.23261
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.046656002104282376.
#
# Epoch 00011: val_loss did not improve from 0.23261
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.02799360081553459.
#
# Epoch 00012: val_loss did not improve from 0.23261
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.016796160489320755.
#
# Epoch 00013: val_loss did not improve from 0.23261
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.010077696293592453.
#
# Epoch 00014: val_loss did not improve from 0.23261
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.006046617776155471.
#
# Epoch 00015: val_loss did not improve from 0.23261
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0036279707215726375.
#
# Epoch 00016: val_loss did not improve from 0.23261
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.002176782488822937.
#
# Epoch 00017: val_loss did not improve from 0.23261
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0013060695491731167.
#
# Epoch 00018: val_loss did not improve from 0.23261
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00078364172950387.
#
# Epoch 00019: val_loss did not improve from 0.23261
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.00047018502373248334.
#
# Epoch 00020: val_loss did not improve from 0.23261
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00028211100725457073.
#
# Epoch 00021: val_loss did not improve from 0.23261
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.00016926659736782312.
#
# Epoch 00022: val_loss did not improve from 0.23261
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.00010155995842069388.
#
# Epoch 00023: val_loss did not improve from 0.23261
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00024: val_loss did not improve from 0.23261
#
# Epoch 00025: val_loss did not improve from 0.23261
#
# Epoch 00026: val_loss did not improve from 0.23261
#
# Epoch 00027: val_loss did not improve from 0.23261
#
# Epoch 00028: val_loss did not improve from 0.23261
#
# Epoch 00029: val_loss did not improve from 0.23261
#
# Epoch 00030: val_loss did not improve from 0.23261
#
# Epoch 00031: val_loss did not improve from 0.23261
#
# Epoch 00032: val_loss did not improve from 0.23261
#
# Epoch 00033: val_loss did not improve from 0.23261
#
# Epoch 00034: val_loss did not improve from 0.23261
#
# Epoch 00035: val_loss did not improve from 0.23261
#
# Epoch 00036: val_loss did not improve from 0.23261
#
# Epoch 00037: val_loss did not improve from 0.23261
#
# Epoch 00038: val_loss did not improve from 0.23261
#
# Epoch 00039: val_loss did not improve from 0.23261
#
# Epoch 00040: val_loss did not improve from 0.23261
#
# Epoch 00041: val_loss did not improve from 0.23261
#
# Epoch 00042: val_loss did not improve from 0.23261
#
# Epoch 00043: val_loss did not improve from 0.23261
#
# Epoch 00044: val_loss did not improve from 0.23261
#
# Epoch 00045: val_loss did not improve from 0.23261
#
# Epoch 00046: val_loss did not improve from 0.23261
#
# Epoch 00047: val_loss did not improve from 0.23261
#
# Epoch 00048: val_loss did not improve from 0.23261
#
# Epoch 00049: val_loss did not improve from 0.23261
#
# Epoch 00050: val_loss did not improve from 0.23261
#
# Epoch 00051: val_loss did not improve from 0.23261
#
# Epoch 00052: val_loss did not improve from 0.23261
#
# Epoch 00053: val_loss did not improve from 0.23261
#
# Epoch 00054: val_loss did not improve from 0.23261
#
# Epoch 00055: val_loss did not improve from 0.23261
#
# Epoch 00056: val_loss did not improve from 0.23261
#
# Epoch 00057: val_loss did not improve from 0.23261
#
# Epoch 00058: val_loss did not improve from 0.23261
#
# Epoch 00059: val_loss did not improve from 0.23261
# Epoch 00059: early stopping
# /home/tharindu/Projects/Siamese-Recurrent-Architectures/nn/gru_manhattan.py:95: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   callbacks=callbacks)
# Epoch 00001: val_loss improved from inf to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00002: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00003: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00004: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00005: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00006: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00007: val_loss did not improve from 0.28522
#
# Epoch 00008: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00009: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00010: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00011: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00012: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00013: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00014: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00015: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00016: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00017: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00018: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00019: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00020: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00021: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00022: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00023: val_loss did not improve from 0.28522
#
# Epoch 00024: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00025: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00026: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00027: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00028: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00029: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00030: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00031: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00032: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00033: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00034: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00035: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00036: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00037: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00038: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00039: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00040: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00041: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00042: val_loss did not improve from 0.28522
#
# Epoch 00043: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00044: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00045: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00046: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00047: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00048: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00049: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00050: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
#
# Epoch 00051: val_loss improved from 0.28522 to 0.28522, saving model to models/gru_glove_adadelta_weights.h5
# Epoch 00051: early stopping
#
# Epoch 00001: val_loss improved from inf to 0.26273, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00002: val_loss improved from 0.26273 to 0.26273, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00003: val_loss improved from 0.26273 to 0.26273, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00004: val_loss improved from 0.26273 to 0.26273, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00005: val_loss improved from 0.26273 to 0.26273, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00006: val_loss improved from 0.26273 to 0.26273, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00007: val_loss improved from 0.26273 to 0.26273, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00008: val_loss improved from 0.26273 to 0.26272, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00009: val_loss improved from 0.26272 to 0.26272, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00010: val_loss improved from 0.26272 to 0.26272, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00011: val_loss improved from 0.26272 to 0.26272, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00012: val_loss improved from 0.26272 to 0.26272, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00013: val_loss improved from 0.26272 to 0.26272, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00014: val_loss improved from 0.26272 to 0.26272, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00015: val_loss improved from 0.26272 to 0.26272, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00016: val_loss improved from 0.26272 to 0.26272, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00017: val_loss improved from 0.26272 to 0.26272, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00018: val_loss improved from 0.26272 to 0.26272, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00019: val_loss improved from 0.26272 to 0.26272, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00020: val_loss improved from 0.26272 to 0.26271, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00021: val_loss improved from 0.26271 to 0.26271, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00022: val_loss improved from 0.26271 to 0.26271, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00023: val_loss improved from 0.26271 to 0.26271, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00024: val_loss improved from 0.26271 to 0.26271, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00025: val_loss improved from 0.26271 to 0.26271, saving model to models/gru_fasttext_adadelta_weights.h5
# Epoch 00026: val_loss improved from 0.26271 to 0.26271, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00027: val_loss improved from 0.26271 to 0.26271, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00028: val_loss improved from 0.26271 to 0.26271, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00029: val_loss improved from 0.26271 to 0.26271, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00030: val_loss improved from 0.26271 to 0.26271, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00031: val_loss improved from 0.26271 to 0.26271, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00032: val_loss improved from 0.26271 to 0.26271, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00033: val_loss improved from 0.26271 to 0.26270, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00034: val_loss improved from 0.26270 to 0.26270, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00035: val_loss improved from 0.26270 to 0.26270, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00036: val_loss improved from 0.26270 to 0.26270, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00037: val_loss improved from 0.26270 to 0.26270, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00038: val_loss improved from 0.26270 to 0.26270, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00039: val_loss improved from 0.26270 to 0.26270, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00040: val_loss improved from 0.26270 to 0.26270, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00041: val_loss improved from 0.26270 to 0.26270, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00042: val_loss improved from 0.26270 to 0.26270, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00043: val_loss improved from 0.26270 to 0.26270, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00044: val_loss improved from 0.26270 to 0.26270, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00045: val_loss improved from 0.26270 to 0.26269, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00046: val_loss improved from 0.26269 to 0.26269, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00047: val_loss improved from 0.26269 to 0.26269, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00048: val_loss improved from 0.26269 to 0.26269, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00049: val_loss improved from 0.26269 to 0.26269, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00050: val_loss improved from 0.26269 to 0.26269, saving model to models/gru_fasttext_adadelta_weights.h5
#
# Epoch 00051: val_loss improved from 0.26269 to 0.26269, saving model to models/gru_fasttext_adadelta_weights.h5
# Epoch 00051: early stopping

# %% [markdown]
# ## Conclusions
# MAGRU model outperformed MALSTM model by a good margin when used transfer learning with the same optimizer. The RMSE value improved from 0.163 to 0.144.

# %% [markdown]
# ## MAGRU with thesaurus-based augmentation and transfer learning

# %% [markdown]
# Thesaurus based augmentation is a good way to extend the training set. We extended the training set using thesaures based augmentation to double the size of the available training set of SICK data. And then we loaded the pre-trained weights saved from STS data and trained the network.
#
# The original paper has used only Adadelta optimizer for this experiment.

# %%
import pandas as pd

sick_aug = pd.read_csv("data/sick_aug.csv", header=0)
sick_aug[:10]
# Out:
#                                               sent_1  \
# 0  A man is typing on a machine used for stenography
# 1                      Two men are leaving the stage
# 2  A man is wearing a purple shirt and black leat...
# 3              A man is playing a keyboard in a park
# 4               A cat is playing with a small bottle
# 5            A poor man is being fed snakes and mice
# 6  Two white dogs and one brown dog are chasing a...
# 7  A group of mothers in uniforms is standing nea...
# 8     Two men are riding an orange raft on the shore
# 9              There is no woman tapping her fingers
#
#                                               sent_2  sim          label  \
# 0  There is no person riding a bike along a muddy...  1.0        NEUTRAL
# 1                    Mimes are performing on a stage  3.1        NEUTRAL
# 2  A model is wearing a purple shirt and black le...  4.4     ENTAILMENT
# 3                   A person is playing the keyboard  4.3     ENTAILMENT
# 4                A bottle is being licked by the cat  3.5        NEUTRAL
# 5              A snake is being fed a mouse by a man  2.3        NEUTRAL
# 6  Two white dogs and one brown dog are chasing a...  4.5     ENTAILMENT
# 7  A group of children in uniforms is standing at...  3.3        NEUTRAL
# 8  Two men are getting off of an orange raft on t...  4.2        NEUTRAL
# 9          A woman is tapping her fingers on a table  3.8  CONTRADICTION
#
#    rand_id
# 0   9974.0
# 1   1552.0
# 2   9393.0
# 3   1373.0
# 4   5664.0
# 5   1609.0
# 6   7887.0
# 7    315.0
# 8   6460.0
# 9   2233.0

# %%
import functools as ft

from nn.gru_manhattan import run_gru_benchmark

validation_portion = 0.1
n_hidden = 100
embedding_dim = 300
batch_size = 64
n_epoch = 500

benchmarks = [("GRU-W2V-ADADELTA",
               ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=adadelta,
                          save_weights=None, load_weights="models/gru_w2v_adadelta_weights.h5", model=word2vec)),
              ("GRU-GLOVE-ADADELTA",
               ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=adadelta,
                          save_weights=None, load_weights="models/gru_glove_adadelta_weights.h5", model=glove)),
              ("GRU-FASTTEXT-ADADELTA",
               ft.partial(run_gru_benchmark, validation_portion=validation_portion, n_hidden=n_hidden,
                          embedding_dim=embedding_dim, batch_size=batch_size, n_epoch=n_epoch, optimizer=adadelta,
                          save_weights=None, load_weights="models/gru_fasttext_adadelta_weights.h5", model=fasttext))]

# %%
from math import sqrt

import matplotlib.pyplot as plt
import pandas as pd
import scipy
from sklearn.metrics import mean_squared_error

from preprocessing.normalize import normalize
from utility.run_experiment import run_experiment

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(25, 10))
row = 0
column = 0

sick_train_normlized = normalize(sick_aug, ["sim"])
sick_test_normalized = normalize(sick_test, ["sim"])
for i in range(0, 3):

    sims, trained_model, topic = run_experiment(sick_train_normlized, sick_test_normalized, ['sent_1', 'sent_2'], "sim",
                                                benchmarks[i])
    sick_test_normalized['predicted_sim'] = pd.Series(sims).values
    pearson_correlation = scipy.stats.pearsonr(sims, sick_test_normalized['sim'])[0]
    spearman_correlation = scipy.stats.spearmanr(sims, sick_test_normalized['sim'])[0]
    rmse = sqrt(mean_squared_error(sick_test_normalized['predicted_sim'], sick_test_normalized['sim']))
    textstr = 'RMSE=%.3f\n$Pearson Correlation=%.3f$\n$Spearman Correlation=%.3f$' % (
        rmse, pearson_correlation, spearman_correlation)
    sick_test_sorted = sick_test_normalized.sort_values('sim')
    id = list(range(0, len(sick_test_normalized.index)))
    sick_test_sorted['id'] = pd.Series(id).values

    if i < 3:
        row = 0
        column = i

    sick_test_sorted.plot(kind='scatter', x='id', y='sim', color='DarkBlue', label='Similarity', title=topic,
                          ax=axes[column]);
    sick_test_sorted.plot(kind='scatter', x='id', y='predicted_sim', color='DarkGreen', label='Predicted Similarity',
                          ax=axes[column]);
    axes[column].text(1500, 0.05, textstr, fontsize=12)
# Out:
# /home/tharindu/Projects/Siamese-Recurrent-Architectures/preprocessing/embeddings.py:33: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   dataset.set_value(index, question, q2n)
# /home/tharindu/Projects/Siamese-Recurrent-Architectures/nn/gru.py:82: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   validation_data=([X_validation['left'], X_validation['right']], Y_validation))

# %% [markdown]
# ## Conclusions
# MAGRU model outperformed MALSTM model by a good margin when used transfer learning and thesaurus-based augmentation with the same optimizer. MAGRU recorded 0.140 RMSE value.
